# %%
# %sql

GRANT USE CATALOG ON CATALOG shopstream TO `hariprasanna0116@gmail.com`;

GRANT USE SCHEMA ON SCHEMA shopstream.gold TO `hariprasanna0116@gmail.com`;

GRANT SELECT ON SCHEMA shopstream.gold TO `hariprasanna0116@gmail.com`;
