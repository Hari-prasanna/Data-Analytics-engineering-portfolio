-- %%
USE CATALOG portfolio_tmdb;
USE SCHEMA bronze;

-- 1. Ingest Base Movies
CREATE OR REPLACE TABLE bronze_movies
AS SELECT * FROM parquet.`s3://hari-data-engineering-workspace/tmdb-elt/raw/raw_movies.parquet`;

-- 2. Ingest Movie Details
CREATE OR REPLACE TABLE bronze_movie_details
AS SELECT * FROM parquet.`s3://hari-data-engineering-workspace/tmdb-elt/raw/raw_movie_details.parquet`;

-- 3. Ingest Movie Credits
CREATE OR REPLACE TABLE bronze_movie_credits
AS SELECT * FROM parquet.`s3://hari-data-engineering-workspace/tmdb-elt/raw/raw_movie_credits.parquet`;
